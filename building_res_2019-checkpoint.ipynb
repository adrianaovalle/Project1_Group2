# %%
import pandas as pd
import numpy as np
import csv

# %%
data=[]
csv.field_size_limit(100000000)
field_names=["ACCOUNT","USE_CODE", "BUILDING_NUMBER", "IMPRV_TYPE", "BUILDING_STYLE_CODE", "CLASS_STRUCTURE",\
                      "CLASS_STRUCTURE_DESC", "DEPRECIATION_VALUE", "CAMA_REPLACMENT_COST", "ACCRUED_DEPR_PCT",\
                      "QUALITY","QUALITY_DESC", "DATE_ERECTED", "EFFETIVE_DATE", "YR_REMODEL","YR_ROLL", "APPRAISED_BY",\
                      "APPRAISED_DATE", "NOTE", "IMPR_SQ_FT", "ACTUAL_AREA", "HEAT_AREA", "GROSS_AREA", "EFFECTIVE_AREA",\
                       "BASE_AREA", "PERIMETER", "PERCENT_COMPLETE","NBHD_FACTOR", "RCNLD", "SIZE_INDEX", "LUMP_SUM_ADJ"]

with open('building_res.txt','r')as txtfile:
    csvreader=csv.reader(txtfile, delimiter = '\t')
    print(csvreader)
    for row in csvreader:
        data.append(row)
        
building_res_2019=pd.DataFrame(columns=field_names, data=data)
building_res_2019.head(2)
# Out:
# <_csv.reader object at 0x000002C7A3C12C40>
#                      ACCOUNT USE_CODE BUILDING_NUMBER IMPRV_TYPE  \
# 0  0021440000001                   A1               1       1001
# 1  0021440000008                   A1               1       1001
#
#   BUILDING_STYLE_CODE CLASS_STRUCTURE CLASS_STRUCTURE_DESC DEPRECIATION_VALUE  \
# 0                101              R            Residential             248821
# 1                101              R            Residential               2170
#
#   CAMA_REPLACMENT_COST ACCRUED_DEPR_PCT  ... HEAT_AREA GROSS_AREA  \
# 0               314963          .790000  ...      2537       2803
# 1                 5710          .380000  ...       656        680
#
#   EFFECTIVE_AREA BASE_AREA PERIMETER PERCENT_COMPLETE NBHD_FACTOR      RCNLD  \
# 0           2523      2537       314             1.00      1.5600  159500.64
# 1            664       656       108             1.00      1.5600    1391.03
#
#   SIZE_INDEX LUMP_SUM_ADJ
# 0     .82000        15912
# 1    1.10000          285
#
# [2 rows x 31 columns]
